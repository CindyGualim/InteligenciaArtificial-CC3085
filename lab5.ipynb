# %% [markdown]
# # Lab 5
# Comparación de algoritmos de búsqueda (DFS, BFS, UCS/Dijkstra, Greedy, A*)

# %% [markdown]
# ## Integrantes
# Luis Pedro Lira - 23669

# %% [markdown]
# ---
# ## 1) El Laberinto de DFS y BFS

# %% [markdown]
# ### (a) Configuración del escenario
# - Recurso elegido:
# - Tipo de laberinto: **Simple Random Maze**
# - Parámetros usados (si aplica):

# %%
# TODO: Documentar aquí configuración o enlaces de ejecución.
# (No resolver aún)

# %% [markdown]
# ### (b) Ejecución de BFS
# - Notas de ejecución:
# - Observaciones iniciales:

# %%
# TODO: Evidencia/registro BFS

# %% [markdown]
# ### (c) Ejecución de DFS
# - Notas de ejecución:
# - Observaciones iniciales:

# %%
# TODO: Evidencia/registro DFS

# %% [markdown]
# ### (d) Evidencia requerida
# - [ ] Screenshot resultado final de **BFS** (área total explorada / nodos visitados).
# - [ ] Screenshot resultado final de **DFS** (área total explorada / nodos visitados).

# %% [markdown]
# ### (e) Preguntas de discusión
# 1. ¿Por qué BFS garantiza el camino más corto en este grid y DFS no?
#
# **Respuesta:**
#
# 2. Mencione una desventaja crítica de memoria para BFS y una de optimalidad para DFS.
#
# **Respuesta:**
#
# 3. ¿Cuál es la diferencia visual en la frontera de expansión de ambos?
#
# **Respuesta:**
#
# 4. ¿Qué ocurre si analizamos las soluciones de BFS y DFS en un laberinto generado por Recursive Division?
#
# **Respuesta:**

# %% [markdown]
# ---
# ## 2) La Trampa de la Distancia

# %% [markdown]
# ### (a) Diseño del escenario trampa
# - Recurso elegido:
# - Descripción del muro/obstáculos:
# - Objetivo del diseño: forzar a Greedy a un camino más largo que BFS.

# %%
# TODO: Descripción técnica del escenario trampa

# %% [markdown]
# ### (b) Ejecución de Greedy Search
# - Notas de ejecución:
# - Observaciones iniciales:

# %%
# TODO: Evidencia/registro Greedy

# %% [markdown]
# ### (c) Ejecución de BFS
# - Notas de ejecución:
# - Observaciones iniciales:

# %%
# TODO: Evidencia/registro BFS

# %% [markdown]
# ### (d) Evidencia requerida
# - [ ] Screenshot del **escenario trampa**.
# - [ ] Screenshot de la solución de **Greedy**.
# - [ ] Screenshot de la solución de **BFS**.

# %% [markdown]
# ### (e) Preguntas de discusión
# 1. ¿Puedes dibujar las paredes de tal forma que Greedy Search resulte en un camino de mayor longitud que BFS?
#
# **Respuesta:**
#
# 2. Muestra un escenario donde Greedy toma una ruta ineficiente por seguir ciegamente la línea recta.
#
# **Respuesta:**
#
# 3. ¿Es el algoritmo Greedy óptimo? ¿Por qué?
#
# **Respuesta:**
#
# 4. ¿Cuál algoritmo es generalmente más rápido en ejecución y cuál explora mayor área (nodos visitados)?
#
# **Respuesta:**

# %% [markdown]
# ---
# ## 3) Heurísticas y Pesos

# %% [markdown]
# ### (a) Configuración del escenario
# - Recurso elegido: PathFinding.js o Stanford A*
# - Obstáculos dispersos diseñados:
# - Comentarios del escenario:

# %%
# TODO: Configuración del escenario (descripción)

# %% [markdown]
# ### (b) Ejecución comparativa: A* vs Dijkstra (UCS)
# - Notas de ejecución A*:
# - Notas de ejecución Dijkstra/UCS:

# %% [markdown]
# ### (c) Tabla comparativa
# | Métrica | A* | Dijkstra (UCS) |
# |---|---:|---:|
# | Nodos explorados |  |  |
# | Nodos en frontera al final |  |  |
# | Tiempo de ejecución |  |  |
# | Número de pasos para hallar solución |  |  |
# | Distancia de solución (número de aristas) |  |  |

# %% [markdown]
# ### (d) Evidencia requerida
# - [ ] Screenshot comparación de nodos explorados por A* y Dijkstra/UCS.

# %% [markdown]
# ### (e) Preguntas de discusión
# 1. ¿Se puede alterar el mapa para que A* termine significativamente más rápido que Dijkstra?
#
# **Respuesta:**
#
# 2. ¿Bajo qué condiciones Dijkstra y A* (o weighted A*) encuentran caminos distintos?
#
# **Respuesta:**

# %% [markdown]
# ---
# ## 4) El impacto de la métrica

# %% [markdown]
# ### (a) Configuración del escenario
# - Recurso elegido: PathFinding.js o Stanford A*
# - Obstáculos dispersos diseñados:
# - Comentarios del escenario:

# %%
# TODO: Configuración del escenario (descripción)

# %% [markdown]
# ### (b) Ejecución comparativa: A* Manhattan vs A* Euclideana
# - Notas de ejecución (Manhattan):
# - Notas de ejecución (Euclideana):

# %% [markdown]
# ### (c) Tabla comparativa
# | Métrica | A* Manhattan | A* Euclideana |
# |---|---:|---:|
# | Nodos explorados |  |  |
# | Nodos en frontera al final |  |  |
# | Tiempo de ejecución |  |  |
# | Número de pasos para hallar solución |  |  |
# | Distancia de solución (número de aristas) |  |  |

# %% [markdown]
# ### (d) Evidencia requerida
# - [ ] Screenshot comparación de nodos explorados con Manhattan y Euclideana.

# %% [markdown]
# ### (e) Preguntas de discusión
# 1. ¿Cuál métrica produce los caminos más cortos, Manhattan o Euclideana?
#
# **Respuesta:**

# %% [markdown]
# ---
# ## 5) El "Peor Escenario" (Stress-Test)

# %% [markdown]
# ### (a) Diseño del laberinto falso
# - Recurso elegido: Pathfinding Visualizer o PathFinding.js
# - Descripción del callejón sin salida:
# - Cómo el diseño fuerza retroceso:

# %%
# TODO: Descripción técnica del peor escenario

# %% [markdown]
# ### (b) Comparación Greedy vs A*
# - Nodos explorados por Greedy:
# - Nodos explorados por A*:
# - Observaciones de la mancha de exploración:

# %% [markdown]
# ### (c) Escenario con Weight (pantano/río)
# - Valor(es) de peso utilizados:
# - Ubicación de inicio y fin:
# - ¿La línea recta cruza el pantano?:
# - ¿Existe camino limpio alternativo?:

# %% [markdown]
# ### (d) Evidencia requerida
# - [ ] Screenshot mancha de nodos visitados por **Greedy** y **A***.
# - [ ] Screenshot del experimento con **Weight** (Dijkstra vs A*).
# - [ ] Screenshot donde se vea si A* intentó entrar al pantano antes de descartarlo.

# %% [markdown]
# ### (e) Preguntas de discusión
# 1. ¿En qué casos específicos Greedy termina siendo "más rápido" pero con una solución desastrosa en distancia?
#
# **Respuesta:**
#
# 2. ¿Existe algún escenario donde A* visite más nodos que BFS?
#
# **Respuesta:**
#
# 3. Compara cómo Dijkstra y A* manejan el peso del pantano/río.
#
# **Respuesta:**
#
# 4. ¿Cómo afecta el peso de las celdas a la función f(n) = g(n) + h(n)?
#
# **Respuesta:**
#
# 5. Si aumentamos el peso del pantano al infinito, ¿en qué algoritmo se convierte Dijkstra?
#
# **Respuesta:**

# %% [markdown]
# ---
# ## Checklist final de entrega
# - [ ] Ejercicio 1 completo (evidencia + respuestas).
# - [ ] Ejercicio 2 completo (evidencia + respuestas).
# - [ ] Ejercicio 3 completo (tabla + evidencia + respuestas).
# - [ ] Ejercicio 4 completo (tabla + evidencia + respuesta).
# - [ ] Ejercicio 5 completo (stress-test + weight + respuestas).
# - [ ] Redacción final revisada.
